# %%
# 다운로드
# https://github.com/UB-Mannheim/tesseract/wiki

# 환경변수 등록
# https://junyoung-jamong.github.io/computer/vision,/ocr/2019/01/30/Python%EC%97%90%EC%84%9C-Tesseract%EB%A5%BC-%EC%9D%B4%EC%9A%A9%ED%95%B4-OCR-%EC%88%98%ED%96%89%ED%95%98%EA%B8%B0.html
# https://github.com/tesseract-ocr/tesseract/issues/1799

# 코드
# https://shinminyong.tistory.com/5

# %%
from PIL import Image
import pytesseract

# %%
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# %%
img = Image.open('thumbnail.png')

# %%
text = pytesseract.image_to_string(img,lang='kor')

# %%
print(text)
# Out:
# 쇄
#
# 실시간라이브방송

# %%
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1280x720 at 0x2090EAAC4A8>
